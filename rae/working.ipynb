# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from scipy.stats import levene, ttest_ind
from sklearn.ensemble import RandomForestClassifier
from sklearn.impute import SimpleImputer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, plot_confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeClassifier, plot_tree, export_text
import math
import numpy as np
import os
import pandas as pd
import requests
import seaborn as sns
import statsmodels.api as sm
import warnings
warnings.filterwarnings("ignore")

# %%
sns.set(rc={'figure.figsize':(16,9)})

# %%
df = pd.read_csv('train_data.csv')

# %%
df.head(25)
# Out:
#     index  lat       lon startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0       0  0.0  0.833333    9/1/14                              237.00
# 1       1  0.0  0.833333    9/2/14                              228.90
# 2       2  0.0  0.833333    9/3/14                              220.69
# 3       3  0.0  0.833333    9/4/14                              225.28
# 4       4  0.0  0.833333    9/5/14                              237.24
# 5       5  0.0  0.833333    9/6/14                              237.87
# 6       6  0.0  0.833333    9/7/14                              236.36
# 7       7  0.0  0.833333    9/8/14                              233.36
# 8       8  0.0  0.833333    9/9/14                              233.82
# 9       9  0.0  0.833333   9/10/14                              229.74
# 10     10  0.0  0.833333   9/11/14                              220.59
# 11     11  0.0  0.833333   9/12/14                              208.32
# 12     12  0.0  0.833333   9/13/14                              198.76
# 13     13  0.0  0.833333   9/14/14                              196.75
# 14     14  0.0  0.833333   9/15/14                              195.16
# 15     15  0.0  0.833333   9/16/14                              195.87
# 16     16  0.0  0.833333   9/17/14                              197.96
# 17     17  0.0  0.833333   9/18/14                              201.64
# 18     18  0.0  0.833333   9/19/14                              201.59
# 19     19  0.0  0.833333   9/20/14                              204.63
# 20     20  0.0  0.833333   9/21/14                              216.39
# 21     21  0.0  0.833333   9/22/14                              228.88
# 22     22  0.0  0.833333   9/23/14                              230.29
# 23     23  0.0  0.833333   9/24/14                              232.52
# 24     24  0.0  0.833333   9/25/14                              238.10
#
#     nmme0-tmp2m-34w__cancm30  nmme0-tmp2m-34w__cancm40  \
# 0                      29.02                     31.64
# 1                      29.02                     31.64
# 2                      29.02                     31.64
# 3                      29.02                     31.64
# 4                      29.02                     31.64
# 5                      29.02                     31.64
# 6                      29.02                     31.64
# 7                      29.02                     31.64
# 8                      29.02                     31.64
# 9                      29.02                     31.64
# 10                     29.02                     31.64
# 11                     29.02                     31.64
# 12                     29.02                     31.64
# 13                     29.02                     31.64
# 14                     29.02                     31.64
# 15                     29.02                     31.64
# 16                     29.02                     31.64
# 17                     29.02                     31.64
# 18                     29.02                     31.64
# 19                     29.02                     31.64
# 20                     29.02                     31.64
# 21                     29.02                     31.64
# 22                     26.87                     27.15
# 23                     26.87                     27.15
# 24                     26.87                     27.15
#
#     nmme0-tmp2m-34w__ccsm30  nmme0-tmp2m-34w__ccsm40  nmme0-tmp2m-34w__cfsv20  \
# 0                     29.57                    30.73                    29.71
# 1                     29.57                    30.73                    29.71
# 2                     29.57                    30.73                    29.71
# 3                     29.57                    30.73                    29.71
# 4                     29.57                    30.73                    29.71
# 5                     29.57                    30.73                    29.71
# 6                     29.57                    30.73                    29.71
# 7                     29.57                    30.73                    29.71
# 8                     29.57                    30.73                    29.71
# 9                     29.57                    30.73                    29.71
# 10                    29.57                    30.73                    29.71
# 11                    29.57                    30.73                    29.71
# 12                    29.57                    30.73                    29.71
# 13                    29.57                    30.73                    29.71
# 14                    29.57                    30.73                    29.71
# 15                    29.57                    30.73                    29.71
# 16                    29.57                    30.73                    29.71
# 17                    29.57                    30.73                    29.71
# 18                    29.57                    30.73                    29.71
# 19                    29.57                    30.73                    29.71
# 20                    29.57                    30.73                    29.71
# 21                    29.57                    30.73                    29.71
# 22                    28.18                    27.88                    27.03
# 23                    28.18                    27.88                    27.03
# 24                    28.18                    27.88                    27.03
#
#     ...  wind-vwnd-925-2010-11  wind-vwnd-925-2010-12  wind-vwnd-925-2010-13
# 19                  -6.36                  21.30                   1.85
# 20                  -4.42                  28.76                  -2.55
# 21                  -2.62                  29.64                  -7.34
# 22                  -3.91                  27.51                 -11.47
# 23                  -3.36                  23.79                 -13.48
# 24                  -7.14                  20.10                 -13.70
#
#     wind-vwnd-925-2010-20
# 0                    4.58
# 1                    3.42
# 2                    4.82
# 3                    9.74
# 4                   10.95
# 5                   12.09
# 6                   12.76
# 7                   11.65
# 8                    8.39
# 9                    4.96
# 10                   5.65
# 11                   0.96
# 12                  -3.19
# 13                  -7.92
# 14                  -8.99
# 15                  -8.03
# 16                 -10.79
# 17                 -19.62
# 18                 -21.92
# 19                 -20.19
# 20                 -15.88
# 21                 -12.81
# 22                 -18.09
# 23                 -24.45
# 24                 -27.40
#
# [25 rows x 246 columns]

# %%
contest_df = df[['climateregions__climateregion', 'elevation__elevation', 'lat', 'lon', 'startdate',
                 'contest-pevpr-sfc-gauss-14d__pevpr','contest-precip-14d__precip','contest-pres-sfc-gauss-14d__pres',
                 'contest-prwtr-eatm-14d__prwtr','contest-rhum-sig995-14d__rhum','contest-slp-14d__slp',
                 'contest-tmp2m-14d__tmp2m','contest-wind-h10-14d__wind-hgt-10','contest-wind-h100-14d__wind-hgt-100',
                 'contest-wind-h500-14d__wind-hgt-500','contest-wind-h850-14d__wind-hgt-850','contest-wind-uwnd-250-14d__wind-uwnd-250',
                 'contest-wind-uwnd-925-14d__wind-uwnd-925','contest-wind-vwnd-250-14d__wind-vwnd-250',
                 'contest-wind-vwnd-925-14d__wind-vwnd-925']].copy()
contest_df
# Out:
#        climateregions__climateregion  elevation__elevation  lat       lon  \
# 0                                BSh                   200  0.0  0.833333
# 1                                BSh                   200  0.0  0.833333
# 2                                BSh                   200  0.0  0.833333
# 3                                BSh                   200  0.0  0.833333
# 4                                BSh                   200  0.0  0.833333
# ...                              ...                   ...  ...       ...
# 375729                           Dfb                   100  1.0  0.866667
# 375730                           Dfb                   100  1.0  0.866667
# 375731                           Dfb                   100  1.0  0.866667
# 375732                           Dfb                   100  1.0  0.866667
# 375733                           Dfb                   100  1.0  0.866667
#
#        startdate  contest-pevpr-sfc-gauss-14d__pevpr  \
# 0         9/1/14                              237.00
# 1         9/2/14                              228.90
# 2         9/3/14                              220.69
# 3         9/4/14                              225.28
# 4         9/5/14                              237.24
# ...          ...                                 ...
# 375729   8/27/16                              312.05
# 375730   8/28/16                              305.82
# 375731   8/29/16                              311.62
# 375732   8/30/16                              304.54
# 375733   8/31/16                              295.29
#
#         contest-precip-14d__precip  contest-pres-sfc-gauss-14d__pres  \
# 0                            94.31                          98644.97
# 1                           100.85                          98686.80
# 2                           101.25                          98712.85
# 3                           101.90                          98711.70
# 4                            82.95                          98686.46
# ...                            ...                               ...
# 375729                       57.45                          97613.96
# 375730                       53.53                          97631.29
# 375731                       52.12                          97588.69
# 375732                       51.73                          97538.62
# 375733                       51.83                          97536.84
#
#         contest-prwtr-eatm-14d__prwtr  contest-rhum-sig995-14d__rhum  \
# 0                               42.45                          81.72
# 1                               42.66                          82.56
# 2                               43.23                          83.29
# 3                               43.11                          83.26
# 4                               42.98                          82.50
# ...                               ...                            ...
# 375729                          24.32                          70.25
# 375730                          23.92                          71.08
                                      'contest-pres-sfc-gauss-14d__pres':'barometric_pressure',
                                      'contest-prwtr-eatm-14d__prwtr':'all_atmos_precip',
                                      'contest-rhum-sig995-14d__rhum':'relative_humidity',
                                      'contest-slp-14d__slp':'sea_level_press',
                                      'contest-tmp2m-14d__tmp2m':'mean_temp',
                                      'contest-wind-h10-14d__wind-hgt-10':'height_10_mb',
                                      'contest-wind-h100-14d__wind-hgt-100':'height_100_mb',
                                      'contest-wind-h500-14d__wind-hgt-500':'height_500_mb',
                                      'contest-wind-h850-14d__wind-hgt-850':'height_850_mb',
                                      'contest-wind-uwnd-250-14d__wind-uwnd-250':'zonal_wind_250mb',
                                      'contest-wind-uwnd-925-14d__wind-uwnd-925':'zonal_wind_925mb',
                                      'contest-wind-vwnd-250-14d__wind-vwnd-250':'long_wind_250mb',
                                      'contest-wind-vwnd-925-14d__wind-vwnd-925':'long_wind_925mb'
                                     })

# %%
contest_df.columns
# Out:
# Index(['region', 'elevation', 'lat', 'lon', 'startdate', 'potential_evap',
#        'precip', 'barometric_pressure', 'all_atmos_precip',
#        'relative_humidity', 'sea_level_press', 'mean_temp', 'height_10_mb',
#        'height_100_mb', 'height_500_mb', 'height_850_mb', 'zonal_wind_250mb',
#        'zonal_wind_925mb', 'long_wind_250mb', 'long_wind_925mb'],
#       dtype='object')

# %%
contest_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 375734 entries, 0 to 375733
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   region               375734 non-null  object
#  1   elevation            375734 non-null  int64
#  2   lat                  375734 non-null  float64
#  3   lon                  375734 non-null  float64
#  4   startdate            375734 non-null  object
#  5   potential_evap       375734 non-null  float64
#  6   precip               375734 non-null  float64
#  7   barometric_pressure  375734 non-null  float64
#  8   all_atmos_precip     375734 non-null  float64
#  9   relative_humidity    375734 non-null  float64
#  10  sea_level_press      375734 non-null  float64
#  11  mean_temp            375734 non-null  float64
#  12  height_10_mb         375734 non-null  float64
#  13  height_100_mb        375734 non-null  float64
#  14  height_500_mb        375734 non-null  float64
#  15  height_850_mb        375734 non-null  float64
#  16  zonal_wind_250mb     375734 non-null  float64
#  17  zonal_wind_925mb     375734 non-null  float64
#  18  long_wind_250mb      375734 non-null  float64
#  19  long_wind_925mb      375734 non-null  float64
# dtypes: float64(17), int64(1), object(2)
# memory usage: 57.3+ MB

# %%
contest_df.index
# Out:
# RangeIndex(start=0, stop=375734, step=1)

# %%
contest_df.dtypes
# Out:
# region                  object
# elevation                int64
# lat                    float64
# lon                    float64
# startdate               object
# potential_evap         float64
# precip                 float64
# barometric_pressure    float64
# all_atmos_precip       float64
# relative_humidity      float64
# sea_level_press        float64
# mean_temp              float64
# height_10_mb           float64
# height_100_mb          float64
# height_500_mb          float64
# height_850_mb          float64
# zonal_wind_250mb       float64
# zonal_wind_925mb       float64
# long_wind_250mb        float64
# long_wind_925mb        float64
# dtype: object

# %%
contest_df.shape
# Out:
# (375734, 20)

# %%
contest_df.describe()
# Out:
#            elevation            lat            lon  potential_evap  \
# count  375734.000000  375734.000000  375734.000000   375734.000000
# mean     1078.657588       0.592766       0.517964      276.744064
# std       669.219573       0.251744       0.272059      198.085182
# min         0.000000       0.000000       0.000000       -2.310000
# 25%       500.000000       0.409091       0.300000      104.062500
# 50%       900.000000       0.590909       0.533333      250.320000
# 75%      1700.000000       0.818182       0.766667      420.010000
# max      3100.000000       1.000000       1.000000     1185.140000
#
#               precip  barometric_pressure  all_atmos_precip  \
# count  375734.000000        375734.000000     375734.000000
# mean       22.859842         89235.103399         14.298038
# std        32.109036          6509.231609          8.142212
# min         0.000000         74839.940000          2.700000
# 25%         3.790000         83598.717500          8.350000
# 50%        12.180000         89444.930000         12.050000
# 75%        28.840000         94683.830000         17.820000
# max       502.630000        102845.570000         52.660000
#
#        relative_humidity  sea_level_press      mean_temp   height_10_mb  \
# count      375734.000000    375734.000000  375734.000000  375734.000000
# mean           62.766512    101605.888627      11.858568   31071.557568
# std            17.399704       406.331364       9.867901     343.019882
# min            13.250000    100379.210000     -20.358963   29943.150000
# 25%            50.090000    101306.620000       4.818231   30811.990000
# 50%            64.910000    101511.245000      12.285770   31016.820000
# 75%            77.410000    101844.870000      19.441170   31374.780000
# max            98.220000    103275.840000      37.238782   31803.030000
#
#        height_100_mb  height_500_mb  height_850_mb  zonal_wind_250mb  \
# count  375734.000000  375734.000000  375734.000000     375734.000000
# mean    16404.561991    5728.370672    1500.148857         19.467550
# std       196.007401     123.805703      28.774810          8.845528
# min     15750.120000    5289.250000    1353.540000        -10.060000
# 25%     16252.322500    5644.070000    1484.780000         13.700000
# 50%     16381.730000    5732.220000    1503.560000         19.640000
# 75%     16585.427500    5827.680000    1519.670000         25.400000
# max     16762.800000    5958.200000    1588.910000         52.970000
#
#        zonal_wind_925mb  long_wind_250mb  long_wind_925mb
# count     375734.000000    375734.000000    375734.000000
# mean           1.035913        -0.800131         1.006341
# std            1.696025         8.723436         2.086804
# min           -6.840000       -32.880000        -8.000000
# 25%           -0.080000        -6.260000        -0.200000
# 50%            0.950000        -0.280000         0.770000
# 75%            2.080000         5.120000         2.010000
# max            8.110000        29.220000        11.880000

# %%
# Count number of zeros in all columns of Dataframe
for column_name in contest_df.columns:
    column = contest_df[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# Count of zeros in column  region  is :  0
# Count of zeros in column  elevation  is :  2193
# Count of zeros in column  lat  is :  1462
# Count of zeros in column  lon  is :  5848
# Count of zeros in column  startdate  is :  0
# Count of zeros in column  potential_evap  is :  0
# Count of zeros in column  precip  is :  11683
# Count of zeros in column  barometric_pressure  is :  0
# Count of zeros in column  all_atmos_precip  is :  0
# Count of zeros in column  relative_humidity  is :  0
# Count of zeros in column  sea_level_press  is :  0
# Count of zeros in column  mean_temp  is :  0
# Count of zeros in column  height_10_mb  is :  0
# Count of zeros in column  height_100_mb  is :  0
# Count of zeros in column  height_500_mb  is :  0
# Count of zeros in column  height_850_mb  is :  0
# Count of zeros in column  zonal_wind_250mb  is :  23
# Count of zeros in column  zonal_wind_925mb  is :  872
# Count of zeros in column  long_wind_250mb  is :  188
# Count of zeros in column  long_wind_925mb  is :  863

# %%
# examining missing values
print("Missing values distribution: ")
print(contest_df.isnull().mean())
print("")
# Out:
# Missing values distribution:
# region                 0.0
# elevation              0.0
# lat                    0.0
# lon                    0.0
# startdate              0.0
# potential_evap         0.0
# precip                 0.0
# barometric_pressure    0.0
# all_atmos_precip       0.0
# relative_humidity      0.0
# sea_level_press        0.0
# mean_temp              0.0
# height_10_mb           0.0
# height_100_mb          0.0
# height_500_mb          0.0
# height_850_mb          0.0
# zonal_wind_250mb       0.0
# zonal_wind_925mb       0.0
# long_wind_250mb        0.0
# long_wind_925mb        0.0
# dtype: float64

# %%
# use pandas hist()
#contest_df.hist()

# %%
region_df = contest_df.groupby(by=["region"])

# %%
# Count number of zeros in all columns of Dataframe
for column_name in region_df.columns:
    column = region_df[column_name]
    # Get the count of Zeros in column 
    count = (column == 0).sum()
    print('Count of zeros in column ', column_name, ' is : ', count)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 # Count number of zeros in all columns of Dataframe
# ----> 2 for column_name in region_df.columns:
#       3     column = region_df[column_name]
#       4     # Get the count of Zeros in column
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'columns'

# %%
z_by_region = contest_df.groupby("region").count(contest_df['zonal_wind_250mb'] == 0).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 1>()
# ----> 1 z_by_region = contest_df.groupby("region").count(contest_df['zonal_wind_250mb'] == 0).sum()
#
# TypeError: count() takes 1 positional argument but 2 were given

# %%
grp=contest_df.groupby(['region'])

# %%
selected_group = grp.get_group(contest_df['zonal_wind_250mb'])
selected_group
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [38], in <cell line: 1>()
# ----> 1 selected_group = grp.get_group(contest_df['zonal_wind_250mb'])
#       2 selected_group
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:745, in BaseGroupBy.get_group(self, name, obj)
#     742 if obj is None:
#     743     obj = self._selected_obj
# --> 745 inds = self._get_index(name)
#     746 if not len(inds):
#     747     raise KeyError(name)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:673, in BaseGroupBy._get_index(self, name)
#     668 @final
#     669 def _get_index(self, name):
#     670     """
#     671     Safe get index, translate keys for datelike to underlying repr.
#     672     """
# --> 673     return self._get_indices([name])[0]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:666, in BaseGroupBy._get_indices(self, names)
#     663     converter = get_converter(index_sample)
#     664     names = (converter(name) for name in names)
# --> 666 return [self.indices.get(name, []) for name in names]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:666, in <listcomp>(.0)
#     663     converter = get_converter(index_sample)
#     664     names = (converter(name) for name in names)
# --> 666 return [self.indices.get(name, []) for name in names]
#
# TypeError: unhashable type: 'Series'

# %%
selected_group['zonal_wind_250mb']=='0']

# %%
contest_df.region.query('zonal_wind_250mb=="0"')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [39], in <cell line: 1>()
# ----> 1 contest_df.region.query('zonal_wind_250mb=="0"')
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
regions = contest_df.groupby(['region', 'zonal_wind_250mb'])

# %%
regions.query("zonal_wind_250mb == 0")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [41], in <cell line: 1>()
# ----> 1 regions.query("zonal_wind_250mb == 0")
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py:904, in GroupBy.__getattr__(self, attr)
#     901 if attr in self.obj:
#     902     return self[attr]
# --> 904 raise AttributeError(
#     905     f"'{type(self).__name__}' object has no attribute '{attr}'"
#     906 )
#
# AttributeError: 'DataFrameGroupBy' object has no attribute 'query'

# %%
region_df =contest_df.groupby[(contest_df.region) & (contest_df.zonal_wind_250mb == 0)]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:301, in na_logical_op(x, y, op)
#     292 try:
#     293     # For exposition, write:
#     294     #  yarr = isinstance(y, np.ndarray)
#    (...)
#     299     # Then Cases where this goes through without raising include:
#     300     #  (xint or xbool) and (yint or bool)
# --> 301     result = op(x, y)
#     302 except TypeError:
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Input In [43], in <cell line: 1>()
# ----> 1 region_df =contest_df.groupby[(contest_df.region) & (contest_df.zonal_wind_250mb == 0)]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py:70, in OpsMixin.__and__(self, other)
#      68 @unpack_zerodim_and_defer("__and__")
#      69 def __and__(self, other):
# ---> 70     return self._logical_method(other, operator.and_)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/series.py:5634, in Series._logical_method(self, other, op)
#    5631 lvalues = self._values
#    5632 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 5634 res_values = ops.logical_op(lvalues, rvalues, op)
#    5635 return self._construct_result(res_values, name=res_name)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:391, in logical_op(left, right, op)
#     387 # For int vs int `^`, `|`, `&` are bitwise operators and return
#     388 #   integer dtypes.  Otherwise these are boolean ops
#     389 filler = fill_int if is_self_int_dtype and is_other_int_dtype else fill_bool
# --> 391 res_values = na_logical_op(lvalues, rvalues, op)
#     392 # error: Cannot call function of unknown type
#     393 res_values = filler(res_values)  # type: ignore[operator]
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py:308, in na_logical_op(x, y, op)
#     306     x = ensure_object(x)
#     307     y = ensure_object(y)
# --> 308     result = libops.vec_binop(x.ravel(), y.ravel(), op)
#     309 else:
#     310     # let null fall thru
#     311     assert lib.is_scalar(y)
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx:252, in pandas._libs.ops.vec_binop()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx:245, in pandas._libs.ops.vec_binop()
#
# TypeError: unsupported operand type(s) for &: 'str' and 'bool'

# %%
mask = (contest_df['zonal_wind_250mb'] == 0)
contest_df[mask]

# %%
df1=contest_df[contest_df['zonal_wind_250mb']==0]['region']

# %%
df1.value_counts()
# Out:
# Cfa    11
# BSk     4
# Dfb     3
# BWk     1
# Csa     1
# Dfa     1
# Csb     1
# Dfc     1
# Name: region, dtype: int64

# %%
df2=contest_df[contest_df['zonal_wind_925mb']==0]['region']

# %%
df2.value_counts()
# Out:
# BSk    352
# Cfa    128
# Csb    120
# Dfb     79
# BWk     44
# Dfa     44
# BWh     29
# Csa     20
# Dfc     20
# Dsb     11
# Cfb     10
# BSh      7
# Dsc      5
# Dwa      2
# Dwb      1
# Name: region, dtype: int64

# %%
df3=contest_df[contest_df['long_wind_250mb']==0]['region']

# %%
df3.value_counts()
# Out:
# BSk    70
# Dfb    29
# Cfa    27
# Csb    21
# Dfa    16
# BWh     5
# Dfc     5
# Csa     4
# Dsb     4
# BWk     3
# Cfb     2
# BSh     1
# Dsc     1
# Name: region, dtype: int64

# %%
df4=contest_df[contest_df['long_wind_925mb']==0]['region']

# %%
df4.value_counts()
# Out:
# BSk    377
# Dfb    145
# Csb     61
# BWk     46
# Dfa     44
# Dfc     43
# Cfa     41
# BWh     30
# Csa     25
# Dsb     24
# Cfb      8
# Dsc      8
# BSh      6
# Dwa      4
# Dwb      1
# Name: region, dtype: int64

# %%
df5=pd.concat([df1,df2,df3,df4], ignore_index=True)

# %%
df5.value_counts()
# Out:
# BSk    803
# Dfb    256
# Cfa    207
# Csb    203
# Dfa    105
# BWk     94
# Dfc     69
# BWh     64
# Csa     50
# Dsb     39
# Cfb     20
# BSh     14
# Dsc     14
# Dwa      6
# Dwb      2
# Name: region, dtype: int64
